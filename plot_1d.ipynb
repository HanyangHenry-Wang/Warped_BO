# %%
import os
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### GP

# %%
with open('GP1d_ei.txt', 'r') as f:
    a = np.loadtxt(f)
with open('GP1d_new_ei.txt', 'r') as f:
    b = np.loadtxt(f)
with open('GP1d_new_acq.txt', 'r') as f:
    c = np.loadtxt(f)
with open('GP1d_erm.txt', 'r') as f:
    d = np.loadtxt(f)

# %%
myxaxis=range(a.shape[1])
N =100

logregret_holder1_new = np.log(a)
logregret_holder2_new = np.log(b)
logregret_holder3_new = np.log(c)
logregret_holder4_new = np.log(d)


logregret_holder1_new[logregret_holder1_new == float('-inf')] = -8
logregret_holder2_new[logregret_holder2_new == float('-inf')] = -8
logregret_holder3_new[logregret_holder3_new == float('-inf')] = -8
logregret_holder4_new[logregret_holder4_new == float('-inf')] = -8
# Out:
# /tmp/ipykernel_18661/1346558859.py:4: RuntimeWarning: divide by zero encountered in log
#   logregret_holder1_new = np.log(a)
# /tmp/ipykernel_18661/1346558859.py:5: RuntimeWarning: divide by zero encountered in log
#   logregret_holder2_new = np.log(b)
# /tmp/ipykernel_18661/1346558859.py:6: RuntimeWarning: divide by zero encountered in log
#   logregret_holder3_new = np.log(c)
# /tmp/ipykernel_18661/1346558859.py:7: RuntimeWarning: divide by zero encountered in log
#   logregret_holder4_new = np.log(d)

# %%
f = plt.figure(figsize=(12,5))
ax = f.add_subplot(121)
ax2 = f.add_subplot(122)

ax.errorbar(myxaxis,np.mean(a,axis=0),np.std(a,axis=0)/np.sqrt(N),label='EI')
ax.errorbar(myxaxis,np.mean(b,axis=0),np.std(b,axis=0)/np.sqrt(N),label='TEI')
ax.errorbar(myxaxis,np.mean(c,axis=0),np.std(c,axis=0)/np.sqrt(N),label='PO')
# ax.errorbar(myxaxis,np.mean(d,axis=0),np.std(d,axis=0)/np.sqrt(N),label='erm')
ax.set_xlabel('Iterations')
ax.set_ylabel('Regret')

ax2.errorbar(myxaxis,np.mean(logregret_holder1_new,axis=0),np.std(logregret_holder1_new,axis=0)/np.sqrt(N),label='EI')
ax2.errorbar(myxaxis,np.mean(logregret_holder2_new,axis=0),np.std(logregret_holder2_new,axis=0)/np.sqrt(N),label='TEI')
ax2.errorbar(myxaxis,np.mean(logregret_holder3_new,axis=0),np.std(logregret_holder3_new,axis=0)/np.sqrt(N),label='PO')
# ax2.errorbar(myxaxis,np.mean(logregret_holder4_new,axis=0),np.std(logregret_holder4_new,axis=0)/np.sqrt(N),label='erm')
ax2.set_xlabel('Iterations')
ax2.set_ylabel('Log Regret')

plt.legend()

# %% [markdown]
# ### Y = X*sin(X)+X*cos(2*X)-1.22

# %%
X = np.linspace(0,10,4001)
Y = X*np.sin(X)+X*np.cos(2*X)-1.22

plt.plot(X,Y)

# %%
np.max(Y)
# Out:
# 9.116788391782412

# %%
with open('function1d_ei.txt', 'r') as f:
    a = np.loadtxt(f)
with open('function1d_new_ei.txt', 'r') as f:
    b = np.loadtxt(f)
with open('function1d_new_acq.txt', 'r') as f:
    c = np.loadtxt(f)
with open('function1d_erm.txt', 'r') as f:
    d = np.loadtxt(f)

# %%
myxaxis=range(a.shape[1])
N =100

logregret_holder1_new = np.log(a)
logregret_holder2_new = np.log(b)
logregret_holder3_new = np.log(c)
logregret_holder4_new = np.log(d)


logregret_holder1_new[logregret_holder1_new == float('-inf')] = -8
logregret_holder2_new[logregret_holder2_new == float('-inf')] = -8
logregret_holder3_new[logregret_holder3_new == float('-inf')] = -8
logregret_holder4_new[logregret_holder4_new == float('-inf')] = -8
# Out:
# /tmp/ipykernel_26630/1346558859.py:4: RuntimeWarning: divide by zero encountered in log
#   logregret_holder1_new = np.log(a)
# /tmp/ipykernel_26630/1346558859.py:5: RuntimeWarning: divide by zero encountered in log
#   logregret_holder2_new = np.log(b)
# /tmp/ipykernel_26630/1346558859.py:6: RuntimeWarning: divide by zero encountered in log
#   logregret_holder3_new = np.log(c)
# /tmp/ipykernel_26630/1346558859.py:7: RuntimeWarning: divide by zero encountered in log
#   logregret_holder4_new = np.log(d)

# %%
f = plt.figure(figsize=(12,5))
ax = f.add_subplot(121)
ax2 = f.add_subplot(122)

ax.errorbar(myxaxis,np.mean(a,axis=0),np.std(a,axis=0)/np.sqrt(N),label='ei')
ax.errorbar(myxaxis,np.mean(b,axis=0),np.std(b,axis=0)/np.sqrt(N),label='new ei')
ax.errorbar(myxaxis,np.mean(c,axis=0),np.std(c,axis=0)/np.sqrt(N),label='new acq')
ax.errorbar(myxaxis,np.mean(d,axis=0),np.std(d,axis=0)/np.sqrt(N),label='erm')
ax.set_xlabel('Iterations')
ax.set_ylabel('Regret')

ax2.errorbar(myxaxis,np.mean(logregret_holder1_new,axis=0),np.std(logregret_holder1_new,axis=0)/np.sqrt(N),label='ei')
ax2.errorbar(myxaxis,np.mean(logregret_holder2_new,axis=0),np.std(logregret_holder2_new,axis=0)/np.sqrt(N),label='new ei')
ax2.errorbar(myxaxis,np.mean(logregret_holder3_new,axis=0),np.std(logregret_holder3_new,axis=0)/np.sqrt(N),label='new acq')
ax2.errorbar(myxaxis,np.mean(logregret_holder4_new,axis=0),np.std(logregret_holder4_new,axis=0)/np.sqrt(N),label='erm')
ax2.set_xlabel('Iterations')
ax2.set_ylabel('Log Regret')

plt.legend()

# %% [markdown]
# ### Y = X*np.sin(X)-0.77

# %%
X = np.linspace(0,10,401)
Y = X*np.sin(X)-0.77
plt.plot(X,Y)

# %%
np.max(Y)
# Out:
# 7.146721824156893

# %%
a = np.genfromtxt(os.path.join(os.getcwd(),'function1d_2_ei'), delimiter=',')
b = np.genfromtxt(os.path.join(os.getcwd(),'function1d_2_new_ei'), delimiter=',')
c = np.genfromtxt(os.path.join(os.getcwd(),'function1d_2_new_acq'), delimiter=',')
d = np.genfromtxt(os.path.join(os.getcwd(),'function1d_2_erm'), delimiter=',')

# %%
myxaxis=range(a.shape[1])
N =100

logregret_holder1_new = np.log(a)
logregret_holder2_new = np.log(b)
logregret_holder3_new = np.log(c)
logregret_holder4_new = np.log(d)


logregret_holder1_new[logregret_holder1_new == float('-inf')] = -8
logregret_holder2_new[logregret_holder2_new == float('-inf')] = -8
logregret_holder3_new[logregret_holder3_new == float('-inf')] = -8
logregret_holder4_new[logregret_holder4_new == float('-inf')] = -8
# Out:
# /tmp/ipykernel_26630/1346558859.py:4: RuntimeWarning: divide by zero encountered in log
#   logregret_holder1_new = np.log(a)
# /tmp/ipykernel_26630/1346558859.py:5: RuntimeWarning: divide by zero encountered in log
#   logregret_holder2_new = np.log(b)
# /tmp/ipykernel_26630/1346558859.py:6: RuntimeWarning: divide by zero encountered in log
#   logregret_holder3_new = np.log(c)
# /tmp/ipykernel_26630/1346558859.py:7: RuntimeWarning: divide by zero encountered in log
#   logregret_holder4_new = np.log(d)

# %%
f = plt.figure(figsize=(12,5))
ax = f.add_subplot(121)
ax2 = f.add_subplot(122)

ax.errorbar(myxaxis,np.mean(a,axis=0),np.std(a,axis=0)/np.sqrt(N),label='ei')
ax.errorbar(myxaxis,np.mean(b,axis=0),np.std(b,axis=0)/np.sqrt(N),label='new ei')
ax.errorbar(myxaxis,np.mean(c,axis=0),np.std(c,axis=0)/np.sqrt(N),label='new acq')
ax.errorbar(myxaxis,np.mean(d,axis=0),np.std(d,axis=0)/np.sqrt(N),label='erm')
ax.set_xlabel('Iterations')
ax.set_ylabel('Regret')

ax2.errorbar(myxaxis,np.mean(logregret_holder1_new,axis=0),np.std(logregret_holder1_new,axis=0)/np.sqrt(N),label='ei')
ax2.errorbar(myxaxis,np.mean(logregret_holder2_new,axis=0),np.std(logregret_holder2_new,axis=0)/np.sqrt(N),label='new ei')
ax2.errorbar(myxaxis,np.mean(logregret_holder3_new,axis=0),np.std(logregret_holder3_new,axis=0)/np.sqrt(N),label='new acq')
ax2.errorbar(myxaxis,np.mean(logregret_holder4_new,axis=0),np.std(logregret_holder4_new,axis=0)/np.sqrt(N),label='erm')
ax2.set_xlabel('Iterations')
ax2.set_ylabel('Log Regret')

plt.legend()
