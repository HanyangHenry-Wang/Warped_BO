# %%
import os
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # 2d GP

# %%
total_record_EI = np.genfromtxt(os.path.join(os.getcwd(),'GP2d_EI'), delimiter=' ')
total_record_TEI = np.genfromtxt(os.path.join(os.getcwd(),'GP2d_TEI'), delimiter=' ')
total_record_MES = np.genfromtxt(os.path.join(os.getcwd(),'GP2d_MES'), delimiter=' ')
total_record_PO = np.genfromtxt(os.path.join(os.getcwd(),'GP2d_PO'), delimiter=' ')
total_record_Mixed = np.genfromtxt(os.path.join(os.getcwd(),'GP2d_Mixed'), delimiter=' ')

# %%
N = 100

total_record = np.array(total_record_EI)
total_record[total_record<=0]=10**(-9)
total_record = np.log10(total_record)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,color='blue',label='EI')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N) ,color='blue',alpha=0.25)

total_record = np.array(total_record_TEI)
total_record[total_record<=0]=10**(-9)
total_record = np.log10(total_record)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,color='yellow',label='TEI')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N) ,color='yellow',alpha=0.25)

total_record = np.array(total_record_MES)
total_record[total_record<=0]=10**(-9)
total_record = np.log10(total_record)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,color='red',label='MES')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N) ,color='red',alpha=0.25)

total_record = np.array(total_record_PO)
total_record[total_record<=0]=10**(-9)
total_record = np.log10(total_record)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,color='black',label='PO')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N) ,color='black',alpha=0.25)

total_record = np.array(total_record_Mixed)
total_record[total_record<=0]=10**(-9)
total_record = np.log10(total_record)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,color='green',label='Mixed')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N) ,color='green',alpha=0.25)

plt.ylabel('log10 regret')
plt.xlabel('iterations')
plt.legend()
plt.title('GP 2D')  # use LGBS for all three
# Out:
# Text(0.5, 1.0, 'GP 2D')

# %%
total_record_EI = np.genfromtxt(os.path.join(os.getcwd(),'GP2d_EI'), delimiter=' ')
total_record_TEI = np.genfromtxt(os.path.join(os.getcwd(),'GP2d_TEI_misinformation'), delimiter=' ')
total_record_MES = np.genfromtxt(os.path.join(os.getcwd(),'GP2d_MES_misinformation'), delimiter=' ')
total_record_PO = np.genfromtxt(os.path.join(os.getcwd(),'GP2d_PO_misinformation'), delimiter=' ')

# %%
N = 100

total_record = np.array(total_record_EI)
total_record[total_record<=0]=10**(-9)
total_record = np.log10(total_record)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,color='blue',label='EI')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N) ,color='blue',alpha=0.25)

total_record = np.array(total_record_TEI)
total_record[total_record<=0]=10**(-9)
total_record = np.log10(total_record)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,color='yellow',label='TEI')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N) ,color='yellow',alpha=0.25)

total_record = np.array(total_record_MES)
total_record[total_record<=0]=10**(-9)
total_record = np.log10(total_record)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,color='red',label='MES')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N) ,color='red',alpha=0.25)

total_record = np.array(total_record_PO)
total_record[total_record<=0]=10**(-9)
total_record = np.log10(total_record)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,color='black',label='PO')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N) ,color='black',alpha=0.25)


plt.ylabel('log10 regret')
plt.xlabel('iterations')
plt.legend()
plt.title('GP 2D (misinformation: f*+0.5)')  # use LGBS for all three
# Out:
# Text(0.5, 1.0, 'GP 2D (misinformation: f*+0.5)')

# %% [markdown]
# # Sincos (1d)

# %%
total_record_EI = np.genfromtxt(os.path.join(os.getcwd(),'Sincos_EI'), delimiter=' ')
total_record_MES = np.genfromtxt(os.path.join(os.getcwd(),'Sincos_MES'), delimiter=' ')
total_record_PO = np.genfromtxt(os.path.join(os.getcwd(),'Sincos_PO'), delimiter=' ')
total_record_Mixed = np.genfromtxt(os.path.join(os.getcwd(),'Sincos_Mixed'), delimiter=' ')

# %%
N = 20
fstar = 0.15985376279886299+0.26

total_record = fstar-np.array(total_record_EI)
total_record[total_record<=0]=10**(-9)
total_record = np.log10(total_record)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,color='blue',label='EI')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N) ,color='blue',alpha=0.25)

total_record = fstar-np.array(total_record_MES)
total_record[total_record<=0]=10**(-9)
total_record = np.log10(total_record)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,color='red',label='MES')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N) ,color='red',alpha=0.25)

total_record = fstar-np.array(total_record_PO)
total_record[total_record<=0]=10**(-9)
total_record = np.log10(total_record)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,color='black',label='PO')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N) ,color='black',alpha=0.25)

total_record = fstar-np.array(total_record_Mixed)
total_record[total_record<=0]=10**(-9)
total_record = np.log10(total_record)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,color='green',label='Mixed')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N) ,color='green',alpha=0.25)

plt.ylabel('log10 regret')
plt.xlabel('iterations')
plt.legend()
plt.title('Sincos 1d')  # use LGBS for all three
# Out:
# Text(0.5, 1.0, 'Sincos 1d')

# %% [markdown]
# # Fourier (1d)

# %%
total_record_EI = np.genfromtxt(os.path.join(os.getcwd(),'Fourier_EI'), delimiter=' ')
total_record_MES = np.genfromtxt(os.path.join(os.getcwd(),'Fourier_MES'), delimiter=' ')
total_record_PO = np.genfromtxt(os.path.join(os.getcwd(),'Fourier_PO'), delimiter=' ')
total_record_Mixed = np.genfromtxt(os.path.join(os.getcwd(),'Fourier_Mixed'), delimiter=' ')

# %%
N = 20
fstar = 1.22+9.50835043776628 

total_record = fstar-np.array(total_record_EI)
total_record[total_record<=0]=10**(-9)
total_record = np.log10(total_record)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,color='blue',label='EI')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N) ,color='blue',alpha=0.25)

total_record = fstar-np.array(total_record_MES)
total_record[total_record<=0]=10**(-9)
total_record = np.log10(total_record)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,color='red',label='MES')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N) ,color='red',alpha=0.25)

total_record = fstar-np.array(total_record_PO)
total_record[total_record<=0]=10**(-9)
total_record = np.log10(total_record)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,color='black',label='PO')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N) ,color='black',alpha=0.25)

total_record = fstar-np.array(total_record_Mixed)
total_record[total_record<=0]=10**(-9)
total_record = np.log10(total_record)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,color='green',label='Mixed')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N) ,color='green',alpha=0.25)

plt.ylabel('log10 regret')
plt.xlabel('iterations')
plt.legend()
plt.title('Fourier 1d')  # use LGBS for all three
# Out:
# Text(0.5, 1.0, 'Fourier 1d')

# %% [markdown]
# # Sincos (2d)

# %%
total_record_EI = np.genfromtxt(os.path.join(os.getcwd(),'Sincos2d_EI'), delimiter=' ')
total_record_MES = np.genfromtxt(os.path.join(os.getcwd(),'Sincos2d_MES'), delimiter=' ')
total_record_PO = np.genfromtxt(os.path.join(os.getcwd(),'Sincos2d_PO'), delimiter=' ')
total_record_Mixed = np.genfromtxt(os.path.join(os.getcwd(),'Sincos2d_Mixed'), delimiter=' ')

# %%
N = 20
fstar = 1.0310741691325334

total_record = (fstar-np.array(total_record_EI))[:,:10]
total_record[total_record<=0]=10**(-9)
total_record = np.log10(total_record)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,color='blue',label='EI')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N) ,color='blue',alpha=0.25)

total_record = (fstar-np.array(total_record_MES))[:,:10]
total_record[total_record<=0]=10**(-9)
total_record = np.log10(total_record)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,color='red',label='MES')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N) ,color='red',alpha=0.25)

total_record = (fstar-np.array(total_record_PO))[:,:10]
total_record[total_record<=0]=10**(-9)
total_record = np.log10(total_record)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,color='black',label='PO')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N) ,color='black',alpha=0.25)

total_record = (fstar-np.array(total_record_Mixed))[:,:10]
total_record[total_record<=0]=10**(-9)
total_record = np.log10(total_record)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,color='green',label='Mixed')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N) ,color='green',alpha=0.25)

plt.ylabel('log10 regret')
plt.xlabel('iterations')
plt.legend()
plt.title('Sincos 2d')  # use LGBS for all three
# Out:
# Text(0.5, 1.0, 'Sincos 2d')

# %% [markdown]
# # Griewank (2d)

# %%
total_record_EI = np.genfromtxt(os.path.join(os.getcwd(),'Griewank_EI'), delimiter=' ')
total_record_MES = np.genfromtxt(os.path.join(os.getcwd(),'Griewank_MES'), delimiter=' ')
total_record_PO = np.genfromtxt(os.path.join(os.getcwd(),'Griewank_PO'), delimiter=' ')
total_record_Mixed = np.genfromtxt(os.path.join(os.getcwd(),'Griewank_Mixed'), delimiter=' ')

# %%
N = 20
fstar = 0.

total_record = fstar-np.array(total_record_EI)
total_record[total_record<=0]=10**(-9)
total_record = np.log10(total_record)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,color='blue',label='EI')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N) ,color='blue',alpha=0.25)

total_record = fstar-np.array(total_record_MES)
total_record[total_record<=0]=10**(-9)
total_record = np.log10(total_record)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,color='red',label='MES')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N) ,color='red',alpha=0.25)

total_record = fstar-np.array(total_record_PO)
total_record[total_record<=0]=10**(-9)
total_record = np.log10(total_record)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,color='black',label='PO')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N) ,color='black',alpha=0.25)

total_record = fstar-np.array(total_record_Mixed)
total_record[total_record<=0]=10**(-9)
total_record = np.log10(total_record)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,color='green',label='Mixed')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N) ,color='green',alpha=0.25)

plt.ylabel('log10 regret')
plt.xlabel('iterations')
plt.legend()
plt.title('Griewank 2d')  # use LGBS for all three
# Out:
# Text(0.5, 1.0, 'Griewank 2d')

# %% [markdown]
# # Beale (2d)

# %%
total_record_EI = np.genfromtxt(os.path.join(os.getcwd(),'Beale_EI'), delimiter=' ')
total_record_MES = np.genfromtxt(os.path.join(os.getcwd(),'Beale_MES'), delimiter=' ')
total_record_PO = np.genfromtxt(os.path.join(os.getcwd(),'Beale_PO'), delimiter=' ')
total_record_Mixed = np.genfromtxt(os.path.join(os.getcwd(),'Beale_Mixed'), delimiter=' ')

# %%
N = 20
fstar = 0.

total_record = fstar-np.array(total_record_EI)
total_record[total_record<=0]=10**(-9)
total_record = np.log10(total_record)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,color='blue',label='EI')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N) ,color='blue',alpha=0.25)

total_record = fstar-np.array(total_record_MES)
total_record[total_record<=0]=10**(-9)
total_record = np.log10(total_record)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,color='red',label='MES')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N) ,color='red',alpha=0.25)

total_record = fstar-np.array(total_record_PO)
total_record[total_record<=0]=10**(-9)
total_record = np.log10(total_record)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,color='black',label='PO')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N) ,color='black',alpha=0.25)

total_record = fstar-np.array(total_record_Mixed)
total_record[total_record<=0]=10**(-9)
total_record = np.log10(total_record)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,color='green',label='Mixed')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N) ,color='green',alpha=0.25)

plt.ylabel('log10 regret')
plt.xlabel('iterations')
plt.legend()
plt.title('Beale 2d')  # use LGBS for all three
# Out:
# Text(0.5, 1.0, 'Beale 2d')

# %% [markdown]
# # Branin (2d)

# %%
total_record_EI = np.genfromtxt(os.path.join(os.getcwd(),'Branin_EI'), delimiter=' ')
total_record_MES = np.genfromtxt(os.path.join(os.getcwd(),'Branin_MES'), delimiter=' ')
total_record_PO = np.genfromtxt(os.path.join(os.getcwd(),'Branin_PO'), delimiter=' ')
total_record_Mixed = np.genfromtxt(os.path.join(os.getcwd(),'Branin_Mixed'), delimiter=' ')

# %%
N = 20
fstar = -0.397887

total_record = fstar-np.array(total_record_EI)
total_record[total_record<=0]=10**(-9)
total_record = np.log10(total_record)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,color='blue',label='EI')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N) ,color='blue',alpha=0.25)

total_record = fstar-np.array(total_record_MES)
total_record[total_record<=0]=10**(-9)
total_record = np.log10(total_record)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,color='red',label='MES')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N) ,color='red',alpha=0.25)

total_record = fstar-np.array(total_record_PO)
total_record[total_record<=0]=10**(-9)
total_record = np.log10(total_record)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,color='black',label='PO')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N) ,color='black',alpha=0.25)

total_record = fstar-np.array(total_record_Mixed)
total_record[total_record<=0]=10**(-9)
total_record = np.log10(total_record)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,color='green',label='Mixed')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N) ,color='green',alpha=0.25)

plt.ylabel('log10 regret')
plt.xlabel('iterations')
plt.legend()
plt.title('Branin 2d')  # use LGBS for all three
# Out:
# Text(0.5, 1.0, 'Branin 2d')

# %% [markdown]
# # StyblinskiTang (2d)

# %%
total_record_EI = np.genfromtxt(os.path.join(os.getcwd(),'StyblinskiTang_EI'), delimiter=' ')
total_record_MES = np.genfromtxt(os.path.join(os.getcwd(),'StyblinskiTang_MES'), delimiter=' ')
total_record_PO = np.genfromtxt(os.path.join(os.getcwd(),'StyblinskiTang_PO'), delimiter=' ')
#total_record_Mixed = np.genfromtxt(os.path.join(os.getcwd(),'Hartmann_Mixed'), delimiter=' ')

# %%
N = 20
fstar = 39.166*2

total_record = fstar-np.array(total_record_EI)
total_record[total_record<=0]=10**(-9)
total_record = np.log10(total_record)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,color='blue',label='EI')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N) ,color='blue',alpha=0.25)

total_record = fstar-np.array(total_record_MES)
total_record[total_record<=0]=10**(-9)
total_record = np.log10(total_record)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,color='red',label='MES')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N) ,color='red',alpha=0.25)

total_record = fstar-np.array(total_record_PO)
total_record[total_record<=0]=10**(-9)
total_record = np.log10(total_record)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,color='black',label='PO')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N) ,color='black',alpha=0.25)

# total_record = fstar-np.array(total_record_Mixed)
# total_record[total_record<=0]=10**(-9)
# total_record = np.log10(total_record)
# mean = np.mean(total_record,axis=0)
# std = np.std(total_record,axis=0)
# iter = np.array(range(mean.shape[0]))
# plt.plot(mean,linewidth=3,color='green',label='Mixed')
# plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N) ,color='green',alpha=0.25)

plt.ylabel('log10 regret')
plt.xlabel('iterations')
plt.legend()
plt.title('StyblinskiTang 2d')  # use LGBS for all three
# Out:
# Text(0.5, 1.0, 'StyblinskiTang 2d')

# %% [markdown]
# # Hartmann (3d)

# %%
total_record_EI = np.genfromtxt(os.path.join(os.getcwd(),'Hartmann_EI'), delimiter=' ')
total_record_MES = np.genfromtxt(os.path.join(os.getcwd(),'Hartmann_MES'), delimiter=' ')
total_record_PO = np.genfromtxt(os.path.join(os.getcwd(),'Hartmann_PO'), delimiter=' ')
total_record_Mixed = np.genfromtxt(os.path.join(os.getcwd(),'Hartmann_Mixed'), delimiter=' ')

# %%
N = 20
fstar = 3.86278

total_record = fstar-np.array(total_record_EI)
total_record[total_record<=0]=10**(-9)
total_record = np.log10(total_record)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,color='blue',label='EI')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N) ,color='blue',alpha=0.25)

total_record = fstar-np.array(total_record_MES)
total_record[total_record<=0]=10**(-9)
total_record = np.log10(total_record)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,color='red',label='MES')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N) ,color='red',alpha=0.25)

total_record = fstar-np.array(total_record_PO)
total_record[total_record<=0]=10**(-9)
total_record = np.log10(total_record)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,color='black',label='PO')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N) ,color='black',alpha=0.25)

total_record = fstar-np.array(total_record_Mixed)
total_record[total_record<=0]=10**(-9)
total_record = np.log10(total_record)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,color='green',label='Mixed')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N) ,color='green',alpha=0.25)

plt.ylabel('log10 regret')
plt.xlabel('iterations')
plt.legend()
plt.title('Hartmann 3d')  # use LGBS for all three
# Out:
# Text(0.5, 1.0, 'Hartmann 3d')

# %% [markdown]
# # StyblinskiTang (4d)

# %%
total_record_EI = np.genfromtxt(os.path.join(os.getcwd(),'StyblinskiTang4d_EI'), delimiter=' ')
total_record_MES = np.genfromtxt(os.path.join(os.getcwd(),'StyblinskiTang4d_MES'), delimiter=' ')
total_record_PO = np.genfromtxt(os.path.join(os.getcwd(),'StyblinskiTang4d_PO'), delimiter=' ')
#total_record_Mixed = np.genfromtxt(os.path.join(os.getcwd(),'Hartmann_Mixed'), delimiter=' ')

# %%
N = 20
fstar = 39.166166*4

total_record = fstar-np.array(total_record_EI)
total_record[total_record<=0]=10**(-9)
total_record = np.log10(total_record)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,color='blue',label='EI')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N) ,color='blue',alpha=0.25)

total_record = fstar-np.array(total_record_MES)
total_record[total_record<=0]=10**(-9)
total_record = np.log10(total_record)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,color='red',label='MES')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N) ,color='red',alpha=0.25)

total_record = fstar-np.array(total_record_PO)
total_record[total_record<=0]=10**(-9)
total_record = np.log10(total_record)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,color='black',label='PO')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N) ,color='black',alpha=0.25)

# total_record = fstar-np.array(total_record_Mixed)
# total_record[total_record<=0]=10**(-9)
# total_record = np.log10(total_record)
# mean = np.mean(total_record,axis=0)
# std = np.std(total_record,axis=0)
# iter = np.array(range(mean.shape[0]))
# plt.plot(mean,linewidth=3,color='green',label='Mixed')
# plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N) ,color='green',alpha=0.25)

plt.ylabel('log10 regret')
plt.xlabel('iterations')
plt.legend()
plt.title('StyblinskiTang 4d')  # use LGBS for all three
# Out:
# Text(0.5, 1.0, 'StyblinskiTang 4d')
